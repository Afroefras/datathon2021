# %% [markdown]
# # Image Augmentation

# %%
from pathlib import Path

BASE_DIR = Path('/Users/efraflores/Desktop/hub/datathon2021/Scripts/data/test')

# %% [markdown]
# ## Import image

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread(str(BASE_DIR.joinpath('Grogu.jpeg')))
plt.imshow(image)
plt.show()

# %% [markdown]
# ## Correct cv2 color

# %%
# Needs to correct the color with the next line
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.show()

# %% [markdown]
# ## Augmentation

# %%
import albumentations as A

# Instance a Class to transform any image
transform = A.Compose([
    A.RandomCrop(width=220, height=220),
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.9),
])

# %%
# Transform the image
for _ in range(5):
    augmented = transform(image=image)['image']
    plt.imshow(augmented)
    plt.show()
