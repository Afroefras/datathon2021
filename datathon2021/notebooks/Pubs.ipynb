# %% [markdown]
# # Pubs

# %% [markdown]
# ## Parameters

# %%
BASE_DIR = '/Users/efraflores/Desktop/EF/Contests/Datathon_202109/data/datos'
FOLDER_NAME = 'CM29'
FILE_NAME = 'maestro_cm29.csv'
CP_FILE = 'Canarias_municipios.csv'

# %% [markdown]
# ## Import

# %%
from mariachis.models import Pubs
        
pub = Pubs(BASE_DIR, FOLDER_NAME, FILE_NAME, CP_FILE)
print(pub)
# Out:
# File: /Users/efraflores/Desktop/EF/Contests/Datathon_202109/data/datos/CM29/maestro_cm29.csv

# %% [markdown]
# ## Transform

# %%
df, pipe_obj = pub.full_pipeline_pubs(cluster_kwargs={'n_clusters':6, 'kmeans':True}, index='comunity_code', columns='Comercio', aggfunc={'Valor':['count','sum','mean']}, fill_value=0)
df.sample(2)
# Out:
#     comunity_code  Valor_count_Bares  Valor_count_Comerc_vinos  \
# 55          38024                 20                         0
# 61          38031                 20                         5
#
#     Valor_count_Restaurantes  Valor_mean_Bares  Valor_mean_Comerc_vinos  \
# 55                        20             134.6                      0.0
# 61                        20             214.6                     17.0
#
#     Valor_mean_Restaurantes  Valor_sum_Bares  Valor_sum_Comerc_vinos  \
# 55                    38.80             2692                       0
# 61                    82.65             4292                      85
#
#     Valor_sum_Restaurantes cluster
# 55                     776       B
# 61                    1653       D

# %% [markdown]
# ## Profiles

# %%
from mariachis.utils import profiles

prof = profiles(df)

for var in prof.values():
    display(var.fillna(0).style.format("{:.0f}").background_gradient('Blues'))
# Out:
# <style type="text/css">
# #T_71895_row0_col0, #T_71895_row0_col1, #T_71895_row0_col2, #T_71895_row0_col4, #T_71895_row0_col7, #T_71895_row1_col0, #T_71895_row1_col3, #T_71895_row1_col5, #T_71895_row1_col6, #T_71895_row1_col8, #T_71895_row2_col0, #T_71895_row2_col2, #T_71895_row3_col0, #T_71895_row3_col2, #T_71895_row4_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_71895_row0_col3 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_71895_row0_col5, #T_71895_row0_col8, #T_71895_row2_col1, #T_71895_row2_col4, #T_71895_row2_col7, #T_71895_row2_col9, #T_71895_row3_col1, #T_71895_row3_col9, #T_71895_row4_col0, #T_71895_row5_col2, #T_71895_row5_col3, #T_71895_row5_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_71895_row0_col6 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_71895_row0_col9 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_71895_row1_col1 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_71895_row1_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_71895_row1_col4, #T_71895_row1_col7 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_71895_row1_col9 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_71895_row2_col3 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_71895_row2_col5, #T_71895_row2_col8 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_71895_row2_col6 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_71895_row3_col3 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_71895_row3_col4, #T_71895_row3_col7 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_71895_row3_col5, #T_71895_row3_col8 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_71895_row3_col6 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_71895_row4_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_71895_row4_col2 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_71895_row4_col3, #T_71895_row4_col5 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_71895_row4_col4, #T_71895_row4_col7 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_71895_row4_col6, #T_71895_row4_col8 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_71895_row5_col0 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_71895_row5_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_71895_row5_col4, #T_71895_row5_col7 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_71895_row5_col5 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_71895_row5_col8 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_71895_row5_col9 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# </style>
# <table id="T_71895_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Valor_count_Bares</th>
#       <th class="col_heading level0 col1" >Valor_count_Comerc_vinos</th>
#       <th class="col_heading level0 col2" >Valor_count_Restaurantes</th>
#       <th class="col_heading level0 col3" >Valor_mean_Bares</th>
#       <th class="col_heading level0 col4" >Valor_mean_Comerc_vinos</th>
#       <th class="col_heading level0 col5" >Valor_mean_Restaurantes</th>
#       <th class="col_heading level0 col6" >Valor_sum_Bares</th>
#       <th class="col_heading level0 col7" >Valor_sum_Comerc_vinos</th>
#       <th class="col_heading level0 col8" >Valor_sum_Restaurantes</th>
#       <th class="col_heading level0 col9" >comunity_code</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71895_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_71895_row0_col0" class="data row0 col0" >20</td>
#       <td id="T_71895_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_71895_row0_col2" class="data row0 col2" >20</td>
#       <td id="T_71895_row0_col3" class="data row0 col3" >671</td>
#       <td id="T_71895_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_71895_row0_col5" class="data row0 col5" >499</td>
#       <td id="T_71895_row0_col6" class="data row0 col6" >13418</td>
#       <td id="T_71895_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_71895_row0_col8" class="data row0 col8" >9978</td>
#       <td id="T_71895_row0_col9" class="data row0 col9" >37266</td>
#     </tr>
#     <tr>
#       <th id="T_71895_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_71895_row1_col0" class="data row1 col0" >20</td>
#       <td id="T_71895_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_71895_row1_col2" class="data row1 col2" >20</td>
#       <td id="T_71895_row1_col3" class="data row1 col3" >52</td>
#       <td id="T_71895_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_71895_row1_col5" class="data row1 col5" >31</td>
#       <td id="T_71895_row1_col6" class="data row1 col6" >1048</td>
#       <td id="T_71895_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_71895_row1_col8" class="data row1 col8" >631</td>
#       <td id="T_71895_row1_col9" class="data row1 col9" >36988</td>
#     </tr>
#     <tr>
#       <th id="T_71895_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_71895_row2_col0" class="data row2 col0" >20</td>
#       <td id="T_71895_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_71895_row2_col2" class="data row2 col2" >20</td>
#       <td id="T_71895_row2_col3" class="data row2 col3" >139</td>
#       <td id="T_71895_row2_col4" class="data row2 col4" >30</td>
#       <td id="T_71895_row2_col5" class="data row2 col5" >76</td>
#       <td id="T_71895_row2_col6" class="data row2 col6" >2777</td>
#       <td id="T_71895_row2_col7" class="data row2 col7" >148</td>
#       <td id="T_71895_row2_col8" class="data row2 col8" >1517</td>
#       <td id="T_71895_row2_col9" class="data row2 col9" >38039</td>
#     </tr>
#     <tr>
#       <th id="T_71895_level0_row3" class="row_heading level0 row3" >D</th>
#       <td id="T_71895_row3_col0" class="data row3 col0" >20</td>
#       <td id="T_71895_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_71895_row3_col2" class="data row3 col2" >20</td>
#       <td id="T_71895_row3_col3" class="data row3 col3" >133</td>
#       <td id="T_71895_row3_col4" class="data row3 col4" >10</td>
#       <td id="T_71895_row3_col5" class="data row3 col5" >75</td>
#       <td id="T_71895_row3_col6" class="data row3 col6" >2667</td>
#       <td id="T_71895_row3_col7" class="data row3 col7" >52</td>
#       <td id="T_71895_row3_col8" class="data row3 col8" >1491</td>
#       <td id="T_71895_row3_col9" class="data row3 col9" >38035</td>
#     </tr>
#     <tr>
#       <th id="T_71895_level0_row4" class="row_heading level0 row4" >E</th>
#       <td id="T_71895_row4_col0" class="data row4 col0" >27</td>
#       <td id="T_71895_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_71895_row4_col2" class="data row4 col2" >22</td>
#       <td id="T_71895_row4_col3" class="data row4 col3" >137</td>
#       <td id="T_71895_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_71895_row4_col5" class="data row4 col5" >84</td>
#       <td id="T_71895_row4_col6" class="data row4 col6" >3635</td>
#       <td id="T_71895_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_71895_row4_col8" class="data row4 col8" >1888</td>
#       <td id="T_71895_row4_col9" class="data row4 col9" >35647</td>
#     </tr>
#     <tr>
#       <th id="T_71895_level0_row5" class="row_heading level0 row5" >F</th>
#       <td id="T_71895_row5_col0" class="data row5 col0" >26</td>
#       <td id="T_71895_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_71895_row5_col2" class="data row5 col2" >25</td>
#       <td id="T_71895_row5_col3" class="data row5 col3" >779</td>
#       <td id="T_71895_row5_co
# <style type="text/css">
# #T_bb601_row0_col0, #T_bb601_row1_col1, #T_bb601_row2_col2, #T_bb601_row3_col3, #T_bb601_row4_col4, #T_bb601_row5_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_bb601_row0_col1, #T_bb601_row0_col2, #T_bb601_row0_col3, #T_bb601_row0_col4, #T_bb601_row0_col5, #T_bb601_row1_col0, #T_bb601_row1_col2, #T_bb601_row1_col3, #T_bb601_row1_col4, #T_bb601_row1_col5, #T_bb601_row2_col0, #T_bb601_row2_col1, #T_bb601_row2_col3, #T_bb601_row2_col4, #T_bb601_row2_col5, #T_bb601_row3_col0, #T_bb601_row3_col1, #T_bb601_row3_col2, #T_bb601_row3_col4, #T_bb601_row3_col5, #T_bb601_row4_col0, #T_bb601_row4_col1, #T_bb601_row4_col2, #T_bb601_row4_col3, #T_bb601_row4_col5, #T_bb601_row5_col0, #T_bb601_row5_col1, #T_bb601_row5_col2, #T_bb601_row5_col3, #T_bb601_row5_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_bb601_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="6">n</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >cluster</th>
#       <th class="col_heading level1 col0" >A</th>
#       <th class="col_heading level1 col1" >B</th>
#       <th class="col_heading level1 col2" >C</th>
#       <th class="col_heading level1 col3" >D</th>
#       <th class="col_heading level1 col4" >E</th>
#       <th class="col_heading level1 col5" >F</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb601_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_bb601_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_bb601_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_bb601_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_bb601_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_bb601_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_bb601_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_bb601_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_bb601_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_bb601_row1_col1" class="data row1 col1" >58</td>
#       <td id="T_bb601_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_bb601_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_bb601_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_bb601_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_bb601_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_bb601_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_bb601_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_bb601_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_bb601_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_bb601_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_bb601_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_bb601_level0_row3" class="row_heading level0 row3" >D</th>
#       <td id="T_bb601_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_bb601_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_bb601_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_bb601_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_bb601_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_bb601_row3_col5" class="data row3 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_bb601_level0_row4" class="row_heading level0 row4" >E</th>
#       <td id="T_bb601_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_bb601_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_bb601_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_bb601_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_bb601_row4_col4" class="data row4 col4" >11</td>
#       <td id="T_bb601_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_bb601_level0_row5" class="row_heading level0 row5" >F</th>
#       <td id="T_bb601_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_bb601_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_bb601_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_bb601_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_bb601_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_bb601_row5_col5" class="data row5 col5" >4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Export

# %%
pub.export_result(df, 'Finished_Pubs.csv')
# Out:
# Exported succesfully!
# File:	Finished_Pubs.csv
# Path:	/Users/efraflores/Desktop/EF/Contests/Datathon_202109/data/datos
