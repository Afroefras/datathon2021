# %% [markdown]
# # Web Scraping from wikipedia

# %% [markdown]
# ## API

# %% [markdown]
# Documentation here <https://pypi.org/project/Wikipedia-API/>

# %%
from typing import Dict
from wikipediaapi import Wikipedia

class WikiDict(Wikipedia):
    def __init__(self) -> None:
        super().__init__(language='en')

    def page_to_dict(self, page: str, feature_list=['title','summary','fullurl','sections','links']) -> Dict:
        search = self.page(page)
        page_dict = {}
        for feature in feature_list:
            page_dict[feature] = eval(f'search.{feature}')
        return page_dict

wiki = WikiDict()

# %%
import pandas as pd

df = pd.DataFrame({'Program':['Python (programming language)','SQL','JavaScript']})
df
# Out:
#                          Program
# 0  Python (programming language)
# 1                            SQL
# 2                     JavaScript

# %%
df['wiki'] = df['Program'].map(wiki.page_to_dict)
df
# Out:
#                          Program  \
# 0  Python (programming language)
# 1                            SQL
# 2                     JavaScript
#
#                                                 wiki
# 0  {'title': 'Python (programming language)', 'su...
# 1  {'title': 'SQL', 'summary': 'SQL ( (listen) S-...
# 2  {'title': 'JavaScript', 'summary': 'JavaScript...

# %%
df = df.join(pd.DataFrame(df['wiki'].tolist(), index=df.index))
df
# Out:
#                          Program  \
# 0  Python (programming language)
# 1                            SQL
# 2                     JavaScript
#
#                                                 wiki  \
# 0  {'title': 'Python (programming language)', 'su...
# 1  {'title': 'SQL', 'summary': 'SQL ( (listen) S-...
# 2  {'title': 'JavaScript', 'summary': 'JavaScript...
#
#                            title  \
# 0  Python (programming language)
# 1                            SQL
# 2                     JavaScript
#
#                                              summary  \
# 0  Python is an interpreted high-level general-pu...
# 1  SQL ( (listen) S-Q-L,  "sequel"; Structured Qu...
# 2  JavaScript (), often abbreviated as JS, is a p...
#
#                                              fullurl  \
# 0  https://en.wikipedia.org/wiki/Python_(programm...
# 1                  https://en.wikipedia.org/wiki/SQL
# 2           https://en.wikipedia.org/wiki/JavaScript
#
#                                             sections  \
# 0  [Section: History (1):\nPython was conceived i...
# 1  [Section: History (1):\nSQL was initially deve...
# 2  [Section: History (1):\n\nSubsections (6):\nSe...
#
#                                                links
# 0  {'"Hello, World!" program': "Hello, World!" pr...
# 1  {'.NET Framework': .NET Framework (id: ??, ns:...
# 2  {'.js': .js (id: ??, ns: 0), '360 Secure Brows...

# %% [markdown]
# ## Webscraping

# %% [markdown]
# Tutorial here <https://www.geeksforgeeks.org/how-to-extract-wikipedia-data-in-python/>

# %%
import re
import requests
from bs4 import BeautifulSoup

class WikiSoup:
    def __init__(self) -> None:
        pass

    def page_to_dict(self, page):
        url = f'https://en.wikipedia.org/wiki/{page}'
        search = BeautifulSoup(requests.get(url).text).select('body')[0]
        paragraphs = []
        images = []
        links = []
        headings = []
        remaining_content = []
        # Iterate throught all tags
        for tag in search.find_all():
            if tag.name=="p": paragraphs.append(tag.text)   

            # For Image use img tag
            elif tag.name=="img": images.append(url+tag['src'])

            # For Anchor use a tag
            elif tag.name=="a":
                # convert into string and then check href available in tag or not
                if "href" in str(tag):
                # In href, there might be possible url is not there if url is not there
                    if "https://en.wikipedia.org/w/" not in str(tag['href']):
                        links.append(url+tag['href'])
                    else: links.append(tag['href'])
                        
            # Similarly check for headings
            elif "h" in tag.name: headings.append(tag.text)
                    
            # Remain content will store here
            else: remaining_content.append(tag.text)
        
        page_dict = {}
        for feature in ['paragraphs','images','links','headings','remaining_content']:
            page_dict[feature] = eval(feature)
        
        return page_dict

wiki = WikiSoup()

# %%
import pandas as pd

df = pd.DataFrame({'Program':['Python (programming language)','SQL','JavaScript']})
df
# Out:
#                          Program
# 0  Python (programming language)
# 1                            SQL
# 2                     JavaScript

# %%
df['wiki'] = df['Program'].map(wiki.page_to_dict)
df
# Out:
#                          Program  \
# 0  Python (programming language)
# 1                            SQL
# 2                     JavaScript
#
#                                                 wiki
# 0  {'paragraphs': ['
# ', 'Python is an interpreted...
# 1  {'paragraphs': ['SQL (/ˌɛsˌkjuːˈɛl/ (listen) S...
# 2  {'paragraphs': ['
# ', 'JavaScript (/ˈdʒɑːvəˌskr...

# %%
df = df.join(pd.DataFrame(df['wiki'].tolist(), index=df.index))
df
# Out:
#                          Program  \
# 0  Python (programming language)
# 1                            SQL
# 2                     JavaScript
#
#                                                 wiki  \
# 0  {'paragraphs': ['
# ', 'Python is an interpreted...
# 1  {'paragraphs': ['SQL (/ˌɛsˌkjuːˈɛl/ (listen) S...
# 2  {'paragraphs': ['
# ', 'JavaScript (/ˈdʒɑːvəˌskr...
#
#                                           paragraphs  \
# 0  [\n, Python is an interpreted high-level gener...
# 1  [SQL (/ˌɛsˌkjuːˈɛl/ (listen) S-Q-L,[4] /ˈsiːkw...
# 2  [\n, JavaScript (/ˈdʒɑːvəˌskrɪpt/),[9] often a...
#
#                                               images  \
# 0  [https://en.wikipedia.org/wiki/Python (program...
# 1  [https://en.wikipedia.org/wiki/SQL//upload.wik...
# 2  [https://en.wikipedia.org/wiki/JavaScript//upl...
#
#                                                links  \
# 0  [https://en.wikipedia.org/wiki/Python (program...
# 1  [https://en.wikipedia.org/wiki/SQL#mw-head, ht...
# 2  [https://en.wikipedia.org/wiki/JavaScript/wiki...
#
#                                             headings  \
# 0  [Python (programming language), Paradigm, Desi...
# 1  [SQL, Paradigm, Family, Designed by, Developer...
# 2  [JavaScript, Paradigm, Designed by, First appe...
#
#                                    remaining_content
# 0  [, , \n\n\n\n\n\nPython (programming language)...
# 1  [, , \n\n\n\n\nSQL\n\nFrom Wikipedia, the free...
# 2  [, , \n\n\n\n\n\n\nJavaScript\n\nFrom Wikipedi...
